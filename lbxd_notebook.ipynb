# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
movie_df = pd.read_csv('movies_by_tag.csv')
print(movie_df)
# Out:
#            Winner  Wins                                         Film Name  \
# 0      alex s win     8                                     The Lost Boys
# 1      alex s win     8                                          The Raid
# 2      alex s win     8                                      Ginger Snaps
# 3      alex s win     8                                          D.E.B.S.
# 4      alex s win     8                                    Vampire's Kiss
# 5      alex s win     8                                                Go
# 6      alex s win     8                                              Dick
# 7      alex s win     8                         Slumber Party Massacre II
# 8     stephen win     8              Indiana Jones and the Temple of Doom
# 9     stephen win     8                        O Brother, Where Art Thou?
# 10    stephen win     8                                     Monster House
# 11    stephen win     8                                        The Beyond
# ...
